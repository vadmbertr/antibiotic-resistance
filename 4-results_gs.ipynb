# %%
import pandas as pd

# %%
res_cefta = pd.read_csv("results/grid_search/cv_results__Ceftazidim.csv")
res_cipro = pd.read_csv("results/grid_search/cv_results__Ciprofloxacin.csv")
res_colis = pd.read_csv("results/grid_search/cv_results__Colistin.csv")
res_merop = pd.read_csv("results/grid_search/cv_results__Meropenem.csv")
res_tobra = pd.read_csv("results/grid_search/cv_results__Tobramycin.csv")

# %% [markdown]
# # All

# %%
res_cefta.loc[res_cefta["param_dim_red"].apply(lambda x: "Stab" not in x)].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6197      35.986772      0.741731         0.093059        0.008661
# 6196       3.334701      0.277104         0.056546        0.004875
# 6199      42.872095      1.055414         0.100922        0.007360
# 6150       9.822048      0.057221         0.080377        0.008295
# 6198      10.346598      0.274238         0.063820        0.000448
# ...             ...           ...              ...             ...
# 2312       0.436710      0.006605         0.000000        0.000000
# 2320       0.423023      0.011167         0.000000        0.000000
# 2328       0.424885      0.004979         0.000000        0.000000
# 5734       0.678535      0.016224         0.000000        0.000000
# 0          0.495382      0.016585         0.000000        0.000000
#
#                                               param_clf  \
# 6197  GradientBoostingClassifier(learning_rate=0.01,...
# ...

# %%
res_cipro.loc[res_cipro["param_dim_red"].apply(lambda x: "Stab" not in x)].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                      axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6231      59.745757      1.790962         0.115895        0.008584
# 6207      60.157739      1.438381         0.119632        0.001783
# 31       106.786995      0.866276         0.162636        0.001933
# 6157      37.683033      0.636751         0.177883        0.012495
# 6699      38.306503      0.229899         0.102701        0.011596
# ...             ...           ...              ...             ...
# 2494       0.693592      0.017252         0.000000        0.000000
# 2496       0.508308      0.015855         0.000000        0.000000
# 2504       0.455603      0.026690         0.000000        0.000000
# 2472       0.511103      0.007516         0.000000        0.000000
# 0          0.552113      0.025214         0.000000        0.000000
#
#                                               param_clf  \
# 6231        GradientBoostingClassifier(random_state=15)
# ...

# %%
res_colis.loc[res_colis["param_dim_red"].apply(lambda x: "Stab" not in x)].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                      axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7062      10.397000      0.029800         0.080382        0.003861
# 3986       0.774299      0.023037         0.135403        0.003251
# 6718      10.381786      0.023144         0.075389        0.001398
# 6916       3.169053      0.047988         0.074060        0.001064
# 3700       1.068925      0.076926         0.090397        0.006694
# ...             ...           ...              ...             ...
# 5400       0.547296      0.003891         0.000000        0.000000
# 2264       0.552766      0.022437         0.000000        0.000000
# 5392       0.563809      0.041385         0.000000        0.000000
# 2248       0.534309      0.016659         0.000000        0.000000
# 0          0.590090      0.037396         0.000000        0.000000
#
#                                               param_clf  \
# 7062      SVC(class_weight='balanced', random_state=15)
# ...

# %%
res_merop.loc[res_merop["param_dim_red"].apply(lambda x: "Stab" not in x)].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                      axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6735      40.806580      0.339216         0.105067        0.007551
# 6734       9.836483      0.044418         0.065791        0.000880
# 6726       9.753026      0.188831         0.069791        0.008175
# 6919      40.756055      0.193001         0.110067        0.002319
# 7111      40.594036      0.110174         0.109925        0.000977
# ...             ...           ...              ...             ...
# 1456       0.490899      0.030294         0.000000        0.000000
# 896        0.500025      0.014206         0.000000        0.000000
# 1448       0.471562      0.015697         0.000000        0.000000
# 1440       0.494214      0.012955         0.000000        0.000000
# 0          0.536270      0.043999         0.000000        0.000000
#
#                                               param_clf  \
# 6735  LogisticRegression(class_weight='balanced', ma...
# ...

# %%
res_tobra.loc[res_tobra["param_dim_red"].apply(lambda x: "Stab" not in x)].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                      axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6255      73.482001      1.691269         0.143144        0.001589
# 39       113.923815      1.832436         0.205138        0.012581
# 38        59.234799      0.349639         0.098905        0.009969
# 6231      83.806366      2.712082         0.145692        0.002027
# 6239      90.859921      2.651900         0.147393        0.001988
# ...             ...           ...              ...             ...
# 2472       0.584768      0.022133         0.000000        0.000000
# 2480       0.554040      0.010224         0.000000        0.000000
# 2488       0.565553      0.024090         0.000000        0.000000
# 2492       0.661203      0.012460         0.000000        0.000000
# 0          0.620014      0.026996         0.000000        0.000000
#
#                                               param_clf  \
# 6255  GradientBoostingClassifier(learning_rate=1.0, ...
# ...

# %% [markdown]
# # Par matrice de regresseur

# %%
res_cefta.loc[(res_cefta["param_sel_ind__gpa"] == "passthrough") &
              (res_cefta["param_sel_ind__snps"] == "drop") &
              (res_cefta["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4378       0.602515      0.010255         0.080976        0.007370
# 4410       0.614706      0.032027         0.085990        0.006121
# 4346       0.598817      0.020851         0.084268        0.001326
# 4314       0.595788      0.016150         0.082523        0.003365
# 5754       0.570031      0.004600         0.082931        0.001854
# ...             ...           ...              ...             ...
# 5058       0.702742      0.022124         0.112493        0.005395
# 3354       0.691487      0.025108         0.119556        0.007475
# 3362       0.652171      0.044539         0.107794        0.010137
# 3338       0.653971      0.013864         0.123105        0.003006
# 3346       0.688528      0.019548         0.123995        0.002228
#
#                                               param_clf  \
# 4378  SGDClassifier(class_weight='balanced', penalty...
# ...

# %%
res_cefta.loc[(res_cefta["param_sel_ind__gpa"] == "drop") &
              (res_cefta["param_sel_ind__snps"] == "passthrough") &
              (res_cefta["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5865       0.784192      0.018338         0.146449        0.008937
# 5993       0.817720      0.011331         0.148160        0.009243
# 5737       0.757607      0.018993         0.140925        0.004617
# 5745       0.762875      0.019262         0.132787        0.005918
# 5873       0.748824      0.017502         0.131110        0.006426
# ...             ...           ...              ...             ...
# 7089      30.887377      0.235972         0.122043        0.009132
# 7081      30.776987      0.048223         0.107850        0.008569
# 7193      30.707730      0.143726         0.120387        0.008135
# 7177      30.764528      0.161583         0.105871        0.009721
# 7185      30.893209      0.440882         0.120409        0.003839
#
#                                               param_clf  \
# 5865  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...

# %%
res_cefta.loc[(res_cefta["param_sel_ind__gpa"] == "drop") &
              (res_cefta["param_sel_ind__snps"] == "drop") &
              (res_cefta["param_sel_ind__genexp"] == "passthrough")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4412       0.554394      0.018256         0.083463        0.003555
# 4348       0.556465      0.010015         0.082501        0.004590
# 5756       0.528224      0.007410         0.078914        0.002419
# 5884       0.538205      0.011182         0.080959        0.009418
# 6012       0.536802      0.021199         0.082101        0.006733
# ...             ...           ...              ...             ...
# 5732       0.573883      0.019595         0.000000        0.000000
# 2204       0.540762      0.016831         0.000000        0.000000
# 2108       0.479922      0.006492         0.000000        0.000000
# 2396       0.474248      0.005053         0.000000        0.000000
# 2300       0.482067      0.002784         0.000000        0.000000
#
#                                               param_clf  \
# 4412  SGDClassifier(class_weight='balanced', penalty...
# ...

# %%
res_cipro.loc[(res_cipro["param_sel_ind__gpa"] == "passthrough") &
              (res_cipro["param_sel_ind__snps"] == "drop") &
              (res_cipro["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4346       0.648703      0.016127         0.089572        0.004342
# 6010       0.642923      0.023798         0.088428        0.006702
# 5882       0.644172      0.005716         0.089148        0.002425
# 5754       0.614904      0.029156         0.090502        0.002452
# 5762       0.606790      0.020009         0.087292        0.008590
# ...             ...           ...              ...             ...
# 4650       0.753961      0.014794         0.136446        0.003806
# 3370       0.685985      0.023594         0.113482        0.004753
# 5850       0.657863      0.008046         0.097989        0.004457
# 5842       0.732209      0.009517         0.102191        0.006437
# 4642       0.736767      0.020355         0.130581        0.006805
#
#                                               param_clf  \
# 4346  SGDClassifier(class_weight='balanced', penalty...
# ...

# %%
res_cipro.loc[(res_cipro["param_sel_ind__gpa"] == "drop") &
              (res_cipro["param_sel_ind__snps"] == "passthrough") &
              (res_cipro["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3625       0.803152      0.008199         0.138267        0.003319
# 3633       0.796944      0.008844         0.137289        0.005324
# 5761       0.790379      0.027326         0.145023        0.011483
# 713        0.894985      0.020713         0.148327        0.009448
# 665        1.058759      0.012740         0.142032        0.002164
# ...             ...           ...              ...             ...
# 4641       1.200739      0.021906         0.312905        0.005450
# 3353       1.203611      0.024648         0.308788        0.007761
# 3321       1.138490      0.012670         0.243765        0.004374
# 3329       1.175440      0.015830         0.235644        0.008983
# 3313       1.141652      0.057687         0.253665        0.019561
#
#                                               param_clf  \
# 3625  LogisticRegression(C=10.0, class_weight='balan...
# ...

# %%
res_cipro.loc[(res_cipro["param_sel_ind__gpa"] == "drop") &
              (res_cipro["param_sel_ind__snps"] == "drop") &
              (res_cipro["param_sel_ind__genexp"] == "passthrough")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6076       0.647489      0.061218         0.102472        0.008767
# 5748       0.612958      0.004630         0.093299        0.006251
# 5876       0.652665      0.007050         0.091152        0.001241
# 6004       0.617942      0.014700         0.091116        0.003466
# 4340       0.599930      0.003321         0.090117        0.007216
# ...             ...           ...              ...             ...
# 5636       0.616755      0.007855         0.000000        0.000000
# 2396       0.509400      0.009239         0.000000        0.000000
# 2300       0.527427      0.018594         0.000000        0.000000
# 2588       0.530658      0.034373         0.000000        0.000000
# 2492       0.580997      0.024071         0.000000        0.000000
#
#                                               param_clf  \
# 6076      SVC(class_weight='balanced', random_state=15)
# ...

# %%
res_colis.loc[(res_colis["param_sel_ind__gpa"] == "passthrough") &
              (res_colis["param_sel_ind__snps"] == "drop") &
              (res_colis["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3626       0.726526      0.014899         0.102476        0.006645
# 5754       0.739360      0.023112         0.108703        0.017964
# 6090       0.757516      0.011503         0.114140        0.003553
# 6098       0.739442      0.013944         0.104362        0.004067
# 4314       0.717190      0.009489         0.102474        0.004651
# ...             ...           ...              ...             ...
# 3378       0.839799      0.021340         0.138997        0.005570
# 3370       0.801907      0.010275         0.137845        0.004505
# 178        1.141621      0.044079         0.131930        0.006028
# 650        0.821554      0.015301         0.108760        0.005431
# 154        1.162194      0.024369         0.130195        0.001836
#
#                                               param_clf  \
# 3626  LogisticRegression(class_weight='balanced', ma...
# ...

# %%
res_colis.loc[(res_colis["param_sel_ind__gpa"] == "drop") &
              (res_colis["param_sel_ind__snps"] == "passthrough") &
              (res_colis["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4441       0.927509      0.013530         0.157339        0.011137
# 5969       0.949784      0.014652         0.164663        0.001419
# 5865       0.952204      0.013393         0.173407        0.005146
# 5737       0.967124      0.006416         0.163566        0.003110
# 5993       0.984551      0.013373         0.169273        0.005701
# ...             ...           ...              ...             ...
# 1073       2.670508      0.026519         0.307348        0.015629
# 2225       2.658448      0.030857         0.309960        0.002158
# 225        1.625005      0.045900         0.303718        0.011211
# 561        2.658176      0.045655         0.270091        0.001772
# 329        1.944605      0.025160         0.287755        0.011893
#
#                                               param_clf  \
# 4441  SGDClassifier(alpha=1e-05, class_weight='balan...
# ...

# %%
res_colis.loc[(res_colis["param_sel_ind__gpa"] == "drop") &
              (res_colis["param_sel_ind__snps"] == "drop") &
              (res_colis["param_sel_ind__genexp"] == "passthrough")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4308       0.689504      0.018384         0.092292        0.004928
# 4340       0.658725      0.013535         0.102001        0.003662
# 4300       0.674813      0.013207         0.095465        0.000541
# 4372       0.678887      0.005433         0.102160        0.001748
# 4436       0.681112      0.019918         0.102565        0.002446
# ...             ...           ...              ...             ...
# 2108       0.579793      0.011728         0.000000        0.000000
# 5348       0.737460      0.038869         0.000000        0.000000
# 2300       0.635248      0.045479         0.000000        0.000000
# 5444       0.665547      0.009211         0.000000        0.000000
# 428        0.630042      0.011519         0.000000        0.000000
#
#                                               param_clf  \
# 4308  SGDClassifier(alpha=1e-05, class_weight='balan...
# ...

# %%
res_merop.loc[(res_merop["param_sel_ind__gpa"] == "passthrough") &
              (res_merop["param_sel_ind__snps"] == "drop") &
              (res_merop["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5954       0.622762      0.018046         0.090583        0.001068
# 5762       0.632707      0.014227         0.084842        0.005351
# 674        0.747382      0.017898         0.096320        0.002331
# 770        0.850616      0.008630         0.076854        0.001630
# 762        1.243441      0.018814         0.074708        0.000986
# ...             ...           ...              ...             ...
# 98         0.843783      0.016009         0.115803        0.003021
# 362        1.287077      0.011084         0.096053        0.001458
# 386        1.284462      0.017242         0.106414        0.002608
# 178        0.988765      0.020190         0.109494        0.003353
# 202        1.011995      0.013036         0.119898        0.003624
#
#                                           param_clf  param_clf__learning_rate  \
# 5954  SVC(class_weight='balanced', random_state=15)                       NaN
# ...

# %%
res_merop.loc[(res_merop["param_sel_ind__gpa"] == "drop") &
              (res_merop["param_sel_ind__snps"] == "passthrough") &
              (res_merop["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6001       0.816198      0.009902         0.142638        0.008853
# 5873       0.805689      0.022728         0.142798        0.008491
# 5745       0.794122      0.014070         0.137430        0.007557
# 5737       0.797210      0.016879         0.140398        0.005669
# 5865       0.821719      0.012850         0.148850        0.001371
# ...             ...           ...              ...             ...
# 6289      31.861134      0.421624         0.111065        0.055563
# 6313      32.205666      0.585866         0.130334        0.065192
# 6337      31.519406      0.204042         0.090965        0.045503
# 6145      31.385924      0.155743         0.092252        0.046134
# 6121      31.529344      0.137583         0.087223        0.044242
#
#                                               param_clf  \
# 6001      SVC(class_weight='balanced', random_state=15)
# ...

# %%
res_merop.loc[(res_merop["param_sel_ind__gpa"] == "drop") &
              (res_merop["param_sel_ind__snps"] == "drop") &
              (res_merop["param_sel_ind__genexp"] == "passthrough")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5756       0.571064      0.011411         0.083977        0.001571
# 5884       0.580243      0.002491         0.083210        0.003977
# 6012       0.608499      0.014402         0.090449        0.004493
# 3628       0.602159      0.008454         0.082488        0.001263
# 4380       0.591148      0.008133         0.090790        0.003945
# ...             ...           ...              ...             ...
# 1052       0.583710      0.020718         0.000000        0.000000
# 3476       0.647548      0.010757         0.000000        0.000000
# 3380       0.622762      0.006201         0.000000        0.000000
# 1532       0.497370      0.006636         0.000000        0.000000
# 1436       0.513760      0.007100         0.000000        0.000000
#
#                                               param_clf  \
# 5756      SVC(class_weight='balanced', random_state=15)
# ...

# %%
res_tobra.loc[(res_tobra["param_sel_ind__gpa"] == "passthrough") &
              (res_tobra["param_sel_ind__snps"] == "drop") &
              (res_tobra["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4402       0.713007      0.010942         0.104555        0.004450
# 5738       0.698689      0.014442         0.107592        0.004761
# 6098       0.719546      0.020447         0.102102        0.003638
# 4314       0.712714      0.009161         0.100974        0.004372
# 5754       0.702377      0.019684         0.101356        0.005203
# ...             ...           ...              ...             ...
# 4674       0.850160      0.025434         0.146947        0.007719
# 3370       0.808885      0.023141         0.136771        0.005921
# 4642       0.824604      0.019159         0.158207        0.009057
# 4658       0.795177      0.031732         0.140117        0.004357
# 4650       0.851732      0.034084         0.154062        0.006348
#
#                                               param_clf  \
# 4402  SGDClassifier(class_weight='balanced', penalty...
# ...

# %%
res_tobra.loc[(res_tobra["param_sel_ind__gpa"] == "drop") &
              (res_tobra["param_sel_ind__snps"] == "passthrough") &
              (res_tobra["param_sel_ind__genexp"] == "drop")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5873       0.941040      0.016747         0.164853        0.006216
# 6001       0.929666      0.008009         0.161271        0.010301
# 5745       0.947676      0.021639         0.167331        0.009850
# 5737       0.926575      0.009347         0.169789        0.002714
# 5993       0.963382      0.020921         0.164465        0.007377
# ...             ...           ...              ...             ...
# 4673       1.334117      0.014628         0.312933        0.007696
# 3369       1.303599      0.018947         0.321629        0.023464
# 3361       1.278457      0.030070         0.319127        0.006706
# 4657       1.295025      0.008105         0.304302        0.013322
# 4665       1.290727      0.029912         0.301567        0.013034
#
#                                               param_clf  \
# 5873  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...

# %%
res_tobra.loc[(res_tobra["param_sel_ind__gpa"] == "drop") &
              (res_tobra["param_sel_ind__snps"] == "drop") &
              (res_tobra["param_sel_ind__genexp"] == "passthrough")].\
    sort_values(["mean_test_score", "std_test_score", "rank_test_score"],
                axis=0, ascending=[False, True, True])
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4372       0.687305      0.009198         0.105347        0.007890
# 4444       0.662883      0.017390         0.098862        0.004183
# 5748       0.698941      0.023441         0.103424        0.001938
# 6004       0.679559      0.019869         0.108286        0.008230
# 5876       0.677176      0.011664         0.102190        0.007268
# ...             ...           ...              ...             ...
# 2588       0.597064      0.014082         0.000000        0.000000
# 2300       0.598431      0.016000         0.000000        0.000000
# 2204       0.663175      0.012689         0.000000        0.000000
# 2396       0.572758      0.012325         0.000000        0.000000
# 2492       0.661203      0.012460         0.000000        0.000000
#
#                                               param_clf  \
# 4372  SGDClassifier(class_weight='balanced', penalty...
# ...
