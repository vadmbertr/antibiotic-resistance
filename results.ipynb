# %%
import pandas as pd

# %%
res_cefta = pd.read_csv("results/grid_search/cv_results__Ceftazidim.csv")
res_cipro = pd.read_csv("results/grid_search/cv_results__Ciprofloxacin.csv")
res_colis = pd.read_csv("results/grid_search/cv_results__Colistin.csv")
res_merop = pd.read_csv("results/grid_search/cv_results__Meropenem.csv")
res_tobra = pd.read_csv("results/grid_search/cv_results__Tobramycin.csv")

# %%
res_cefta.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 5749        5749       0.741986      0.008802         0.135252
# 5877        5877       0.750027      0.026864         0.131574
# 6005        6005       0.780747      0.026033         0.141807
# 4412        4412       0.554394      0.018256         0.083463
# 5741        5741       0.795167      0.015035         0.144948
# ...          ...            ...           ...              ...
# 6080        6080       0.499308      0.016886         0.000000
# 6088        6088       0.507894      0.009884         0.000000
# 6096        6096       0.512787      0.012954         0.000000
# 6104        6104       0.523527      0.010624         0.000000
# 6112        6112       0.501075      0.013811         0.000000
#
#       std_score_time                                          param_clf  \
# 5749        0.006708  SVC(C=0.1, class_weight='balanced', kernel='li...
# 5877        0.005303  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6005        0.007796  SVC(C=0.1, class_weight='balanced', kernel='li...
# 4412        0.003555  SGDClassifier(class_weight='balanced', penalty...
# 5741        0.004382  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...              ...                                                ...
# 6080        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6088        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6096        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6104        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6112        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
#
#       param_clf__learning_rate  \
# 5749                       NaN
# 5877                       NaN
# 6005                       NaN
# 4412                       NaN
# 5741                       NaN
# ...                        ...
# 6080                       NaN
# 6088                       NaN
# 6096                       NaN
# 6104                       NaN
# 6112                       NaN
#
#                                           param_dim_red param_sel_ind__genexp  \
# 5749  StabilitySelectionTransformer(stability_scores...           passthrough
# 5877  StabilitySelectionTransformer(stability_scores...           passthrough
# 6005  StabilitySelectionTransformer(stability_scores...           passthrough
# 4412  StabilitySelectionTransformer(stability_scores...           passthrough
# 5741  StabilitySelectionTransformer(stability_scores...           passthrough
# ...                                                 ...                   ...
# 6080  StabilitySelectionTransformer(stability_scores...                  drop
# 6088  StabilitySelectionTransformer(stability_scores...                  drop
# 6096  StabilitySelectionTransformer(stability_scores...                  drop
# 6104  StabilitySelectionTransformer(stability_scores...                  drop
# 6112  StabilitySelectionTransformer(stability_scores...                  drop
#
#      param_sel_ind__gpa  ... param_clf__kernel  \
# 5749               drop  ...            linear
# 5877               drop  ...            linear
# 6005               drop  ...            linear
# 4412               drop  ...               NaN
# 5741               drop  ...            linear
# ...                 ...  ...               ...
# 6080               drop  ...               rbf
# 6088               drop  ...           sigmoid
# 6096               drop  ...           sigmoid
# 6104               drop  ...           sigmoid
# 6112               drop  ...           sigmoid
#
#                                                  params  split0_test_score  \
# 5749  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.909982
# 5877  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.909982
# 6005  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.909982
# 4412  {'clf': SGDClassifier(class_weight='balanced',...           0.834225
# 5741  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.850713
# ...                                                 ...                ...
# 6080  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6088  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6096  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6104  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6112  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
#
#       split1_test_score  split2_test_score split3_test_score  \
# 5749           0.849822           0.866310          0.925134
# 5877           0.849822           0.866310          0.925134
# 6005           0.849822           0.866310          0.925134
# 4412           0.881462           0.778075          0.881016
# 5741           0.820410           0.852496          0.940731
# ...                 ...                ...               ...
# 6080                NaN                NaN               NaN
# 6088                NaN                NaN               NaN
# 6096                NaN                NaN               NaN
# 6104                NaN                NaN               NaN
# 6112                NaN                NaN               NaN
#
#       split4_test_score  mean_test_score  std_test_score rank_test_score
# 5749           0.848485         0.879947        0.031709               1
# 5877           0.848485         0.879947        0.031709               1
# 6005           0.848485         0.879947        0.031709               1
# 4412           0.969697         0.868895        0.063113               4
# 5741           0.878788         0.868627        0.040517               5
# ...                 ...              ...             ...             ...
# 6080                NaN              NaN             NaN            5349
# 6088                NaN              NaN             NaN            5367
# 6096                NaN              NaN             NaN            5354
# 6104                NaN              NaN             NaN            5294
# 6112                NaN              NaN             NaN            5320
#
# [6120 rows x 30 columns]

# %%
res_cipro.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 3645        3645       0.866081      0.005860         0.149011
# 3621        3621       0.829334      0.011305         0.145093
# 3613        3613       0.868188      0.022201         0.145184
# 3653        3653       0.843937      0.031332         0.141939
# 4374        4374       0.634752      0.004966         0.093906
# ...          ...            ...           ...              ...
# 6080        6080       0.584627      0.017884         0.000000
# 6088        6088       0.559758      0.005572         0.000000
# 6096        6096       0.577215      0.004188         0.000000
# 6104        6104       0.570433      0.005631         0.000000
# 6112        6112       0.561198      0.003423         0.000000
#
#       std_score_time                                          param_clf  \
# 3645        0.001761  LogisticRegression(C=10.0, class_weight='balan...
# 3621        0.001220  LogisticRegression(C=10.0, class_weight='balan...
# 3613        0.004348  LogisticRegression(C=10.0, class_weight='balan...
# 3653        0.003100  LogisticRegression(C=10.0, class_weight='balan...
# 4374        0.001747  SGDClassifier(class_weight='balanced', penalty...
# ...              ...                                                ...
# 6080        0.000000      SVC(class_weight='balanced', random_state=15)
# 6088        0.000000      SVC(class_weight='balanced', random_state=15)
# 6096        0.000000      SVC(class_weight='balanced', random_state=15)
# 6104        0.000000      SVC(class_weight='balanced', random_state=15)
# 6112        0.000000      SVC(class_weight='balanced', random_state=15)
#
#       param_clf__learning_rate  \
# 3645                       NaN
# 3621                       NaN
# 3613                       NaN
# 3653                       NaN
# 4374                       NaN
# ...                        ...
# 6080                       NaN
# 6088                       NaN
# 6096                       NaN
# 6104                       NaN
# 6112                       NaN
#
#                                           param_dim_red param_sel_ind__genexp  \
# 3645  StabilitySelectionTransformer(stability_scores...           passthrough
# 3621  StabilitySelectionTransformer(stability_scores...           passthrough
# 3613  StabilitySelectionTransformer(stability_scores...           passthrough
# 3653  StabilitySelectionTransformer(stability_scores...           passthrough
# 4374  StabilitySelectionTransformer(stability_scores...           passthrough
# ...                                                 ...                   ...
# 6080  StabilitySelectionTransformer(stability_scores...                  drop
# 6088  StabilitySelectionTransformer(stability_scores...                  drop
# 6096  StabilitySelectionTransformer(stability_scores...                  drop
# 6104  StabilitySelectionTransformer(stability_scores...                  drop
# 6112  StabilitySelectionTransformer(stability_scores...                  drop
#
#      param_sel_ind__gpa  ... param_clf__kernel  \
# 3645               drop  ...               NaN
# 3621               drop  ...               NaN
# 3613               drop  ...               NaN
# 3653               drop  ...               NaN
# 4374        passthrough  ...               NaN
# ...                 ...  ...               ...
# 6080               drop  ...               rbf
# 6088               drop  ...           sigmoid
# 6096               drop  ...           sigmoid
# 6104               drop  ...           sigmoid
# 6112               drop  ...           sigmoid
#
#                                                  params  split0_test_score  \
# 3645  {'clf': LogisticRegression(C=10.0, class_weigh...           0.931250
# 3621  {'clf': LogisticRegression(C=10.0, class_weigh...           0.950000
# 3613  {'clf': LogisticRegression(C=10.0, class_weigh...           0.934375
# 3653  {'clf': LogisticRegression(C=10.0, class_weigh...           0.962500
# 4374  {'clf': SGDClassifier(class_weight='balanced',...           0.943750
# ...                                                 ...                ...
# 6080  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6088  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6096  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6104  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6112  {'clf': SVC(class_weight='balanced', random_st...                NaN
#
#       split1_test_score  split2_test_score split3_test_score  \
# 3645           0.906250           0.909375          0.917468
# 3621           0.856250           0.937500          0.955929
# 3613           0.859375           0.953125          0.968750
# 3653           0.859375           0.921875          0.901843
# 4374           0.946875           0.909375          0.847756
# ...                 ...                ...               ...
# 6080                NaN                NaN               NaN
# 6088                NaN                NaN               NaN
# 6096                NaN                NaN               NaN
# 6104                NaN                NaN               NaN
# 6112                NaN                NaN               NaN
#
#       split4_test_score  mean_test_score  std_test_score rank_test_score
# 3645           0.905242         0.913917        0.009672               1
# 3621           0.869355         0.913807        0.042271               2
# 3613           0.844355         0.911996        0.050513               3
# 3653           0.901613         0.909441        0.033453               4
# 4374           0.875000         0.904551        0.038601               5
# ...                 ...              ...             ...             ...
# 6080                NaN              NaN             NaN            5366
# 6088                NaN              NaN             NaN            5371
# 6096                NaN              NaN             NaN            5376
# 6104                NaN              NaN             NaN            5380
# 6112                NaN              NaN             NaN            5385
#
# [6120 rows x 30 columns]

# %%
res_colis.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 4308        4308       0.689504      0.018384         0.092292
# 5739        5739       0.991125      0.024692         0.186862
# 5867        5867       1.016182      0.014240         0.186402
# 5995        5995       1.010832      0.021983         0.182406
# 4340        4340       0.658725      0.013535         0.102001
# ...          ...            ...           ...              ...
# 6080        6080       0.662497      0.013708         0.000000
# 6088        6088       0.639384      0.010035         0.000000
# 6096        6096       0.651847      0.010485         0.000000
# 6104        6104       0.664634      0.009381         0.000000
# 6112        6112       0.659146      0.013222         0.000000
#
#       std_score_time                                          param_clf  \
# 4308        0.004928  SGDClassifier(alpha=1e-05, class_weight='balan...
# 5739        0.013193      SVC(class_weight='balanced', random_state=15)
# 5867        0.001724      SVC(class_weight='balanced', random_state=15)
# 5995        0.006908      SVC(class_weight='balanced', random_state=15)
# 4340        0.003662  SGDClassifier(alpha=1e-05, class_weight='balan...
# ...              ...                                                ...
# 6080        0.000000      SVC(class_weight='balanced', random_state=15)
# 6088        0.000000      SVC(class_weight='balanced', random_state=15)
# 6096        0.000000      SVC(class_weight='balanced', random_state=15)
# 6104        0.000000      SVC(class_weight='balanced', random_state=15)
# 6112        0.000000      SVC(class_weight='balanced', random_state=15)
#
#       param_clf__learning_rate  \
# 4308                       NaN
# 5739                       NaN
# 5867                       NaN
# 5995                       NaN
# 4340                       NaN
# ...                        ...
# 6080                       NaN
# 6088                       NaN
# 6096                       NaN
# 6104                       NaN
# 6112                       NaN
#
#                                           param_dim_red param_sel_ind__genexp  \
# 4308  StabilitySelectionTransformer(stability_scores...           passthrough
# 5739  StabilitySelectionTransformer(stability_scores...                  drop
# 5867  StabilitySelectionTransformer(stability_scores...                  drop
# 5995  StabilitySelectionTransformer(stability_scores...                  drop
# 4340  StabilitySelectionTransformer(stability_scores...           passthrough
# ...                                                 ...                   ...
# 6080  StabilitySelectionTransformer(stability_scores...                  drop
# 6088  StabilitySelectionTransformer(stability_scores...                  drop
# 6096  StabilitySelectionTransformer(stability_scores...                  drop
# 6104  StabilitySelectionTransformer(stability_scores...                  drop
# 6112  StabilitySelectionTransformer(stability_scores...                  drop
#
#      param_sel_ind__gpa  ... param_clf__kernel  \
# 4308               drop  ...               NaN
# 5739        passthrough  ...            linear
# 5867        passthrough  ...            linear
# 5995        passthrough  ...            linear
# 4340               drop  ...               NaN
# ...                 ...  ...               ...
# 6080               drop  ...               rbf
# 6088               drop  ...           sigmoid
# 6096               drop  ...           sigmoid
# 6104               drop  ...           sigmoid
# 6112               drop  ...           sigmoid
#
#                                                  params  split0_test_score  \
# 4308  {'clf': SGDClassifier(alpha=1e-05, class_weigh...           0.858734
# 5739  {'clf': SVC(class_weight='balanced', random_st...           0.823529
# 5867  {'clf': SVC(class_weight='balanced', random_st...           0.823529
# 5995  {'clf': SVC(class_weight='balanced', random_st...           0.823529
# 4340  {'clf': SGDClassifier(alpha=1e-05, class_weigh...           0.829323
# ...                                                 ...                ...
# 6080  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6088  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6096  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6104  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6112  {'clf': SVC(class_weight='balanced', random_st...                NaN
#
#       split1_test_score  split2_test_score split3_test_score  \
# 4308           0.829323           0.887255          0.939394
# 5739           0.874777           0.940285          0.969697
# 5867           0.874777           0.940285          0.969697
# 5995           0.874777           0.940285          0.969697
# 4340           0.866310           0.819964          0.925134
# ...                 ...                ...               ...
# 6080                NaN                NaN               NaN
# 6088                NaN                NaN               NaN
# 6096                NaN                NaN               NaN
# 6104                NaN                NaN               NaN
# 6112                NaN                NaN               NaN
#
#       split4_test_score  mean_test_score  std_test_score rank_test_score
# 4308           0.879638         0.878869        0.036316               1
# 5739           0.764706         0.874599        0.074890               2
# 5867           0.764706         0.874599        0.074890               2
# 5995           0.764706         0.874599        0.074890               2
# 4340           0.901357         0.868418        0.040453               5
# ...                 ...              ...             ...             ...
# 6080                NaN              NaN             NaN            5389
# 6088                NaN              NaN             NaN            5372
# 6096                NaN              NaN             NaN            5367
# 6104                NaN              NaN             NaN            5336
# 6112                NaN              NaN             NaN            5323
#
# [6120 rows x 30 columns]

# %%
res_merop.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 3621        3621       0.819493      0.014489         0.141060
# 3671        3671       0.907014      0.008109         0.154736
# 3639        3639       0.844094      0.008518         0.160176
# 3591        3591       0.859932      0.008959         0.157386
# 4423        4423       0.868381      0.021634         0.156757
# ...          ...            ...           ...              ...
# 6080        6080       0.593598      0.004072         0.000000
# 6088        6088       0.583577      0.030113         0.000000
# 6096        6096       0.563024      0.011007         0.000000
# 6104        6104       0.570565      0.015008         0.000000
# 6112        6112       0.579157      0.015430         0.000000
#
#       std_score_time                                          param_clf  \
# 3621        0.005970  LogisticRegression(class_weight='balanced', ma...
# 3671        0.002694  LogisticRegression(class_weight='balanced', ma...
# 3639        0.005902  LogisticRegression(class_weight='balanced', ma...
# 3591        0.007429  LogisticRegression(class_weight='balanced', ma...
# 4423        0.004957  SGDClassifier(class_weight='balanced', penalty...
# ...              ...                                                ...
# 6080        0.000000      SVC(class_weight='balanced', random_state=15)
# 6088        0.000000      SVC(class_weight='balanced', random_state=15)
# 6096        0.000000      SVC(class_weight='balanced', random_state=15)
# 6104        0.000000      SVC(class_weight='balanced', random_state=15)
# 6112        0.000000      SVC(class_weight='balanced', random_state=15)
#
#       param_clf__learning_rate  \
# 3621                       NaN
# 3671                       NaN
# 3639                       NaN
# 3591                       NaN
# 4423                       NaN
# ...                        ...
# 6080                       NaN
# 6088                       NaN
# 6096                       NaN
# 6104                       NaN
# 6112                       NaN
#
#                                           param_dim_red param_sel_ind__genexp  \
# 3621  StabilitySelectionTransformer(stability_scores...           passthrough
# 3671  StabilitySelectionTransformer(stability_scores...           passthrough
# 3639  StabilitySelectionTransformer(stability_scores...           passthrough
# 3591  StabilitySelectionTransformer(stability_scores...           passthrough
# 4423  StabilitySelectionTransformer(stability_scores...           passthrough
# ...                                                 ...                   ...
# 6080  StabilitySelectionTransformer(stability_scores...                  drop
# 6088  StabilitySelectionTransformer(stability_scores...                  drop
# 6096  StabilitySelectionTransformer(stability_scores...                  drop
# 6104  StabilitySelectionTransformer(stability_scores...                  drop
# 6112  StabilitySelectionTransformer(stability_scores...                  drop
#
#      param_sel_ind__gpa  ... param_clf__kernel  \
# 3621               drop  ...               NaN
# 3671        passthrough  ...               NaN
# 3639        passthrough  ...               NaN
# 3591        passthrough  ...               NaN
# 4423        passthrough  ...               NaN
# ...                 ...  ...               ...
# 6080               drop  ...               rbf
# 6088               drop  ...           sigmoid
# 6096               drop  ...           sigmoid
# 6104               drop  ...           sigmoid
# 6112               drop  ...           sigmoid
#
#                                                  params  split0_test_score  \
# 3621  {'clf': LogisticRegression(class_weight='balan...           0.946660
# 3671  {'clf': LogisticRegression(class_weight='balan...           0.921614
# 3639  {'clf': LogisticRegression(class_weight='balan...           0.911410
# 3591  {'clf': LogisticRegression(class_weight='balan...           0.956865
# 4423  {'clf': SGDClassifier(class_weight='balanced',...           0.967069
# ...                                                 ...                ...
# 6080  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6088  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6096  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6104  {'clf': SVC(class_weight='balanced', random_st...                NaN
# 6112  {'clf': SVC(class_weight='balanced', random_st...                NaN
#
#       split1_test_score  split2_test_score split3_test_score  \
# 3621           0.923933           0.946660          0.868275
# 3671           0.969388           0.954545          0.888683
# 3639           0.959184           0.954545          0.888683
# 3591           0.959184           0.868275          0.885436
# 4423           0.923933           0.944341          0.855751
# ...                 ...                ...               ...
# 6080                NaN                NaN               NaN
# 6088                NaN                NaN               NaN
# 6096                NaN                NaN               NaN
# 6104                NaN                NaN               NaN
# 6112                NaN                NaN               NaN
#
#       split4_test_score  mean_test_score  std_test_score rank_test_score
# 3621           0.900568         0.917219        0.029838               1
# 3671           0.850379         0.916922        0.043395               2
# 3639           0.862689         0.915302        0.037303               3
# 3591           0.904356         0.914823        0.037082               4
# 4423           0.877841         0.913787        0.041318               5
# ...                 ...              ...             ...             ...
# 6080                NaN              NaN             NaN            5377
# 6088                NaN              NaN             NaN            5270
# 6096                NaN              NaN             NaN            5342
# 6104                NaN              NaN             NaN            5268
# 6112                NaN              NaN             NaN            5284
#
# [6120 rows x 30 columns]

# %%
res_tobra.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 5742        5742       0.757548      0.010208         0.110660
# 5870        5870       0.746295      0.010066         0.107332
# 5998        5998       0.757955      0.028361         0.111136
# 4406        4406       0.732381      0.033823         0.105398
# 5750        5750       0.719112      0.004041         0.102776
# ...          ...            ...           ...              ...
# 6080        6080       0.637881      0.003928         0.000000
# 6088        6088       0.641405      0.010368         0.000000
# 6096        6096       0.646021      0.012571         0.000000
# 6104        6104       0.658122      0.026550         0.000000
# 6112        6112       0.645639      0.021329         0.000000
#
#       std_score_time                                          param_clf  \
# 5742        0.006098  SVC(C=0.1, class_weight='balanced', kernel='li...
# 5870        0.002027  SVC(C=0.1, class_weight='balanced', kernel='li...
# 5998        0.003721  SVC(C=0.1, class_weight='balanced', kernel='li...
# 4406        0.008176  SGDClassifier(class_weight='balanced', penalty...
# 5750        0.003235  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...              ...                                                ...
# 6080        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6088        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6096        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6104        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
# 6112        0.000000  SVC(C=0.1, class_weight='balanced', kernel='li...
#
#       param_clf__learning_rate  \
# 5742                       NaN
# 5870                       NaN
# 5998                       NaN
# 4406                       NaN
# 5750                       NaN
# ...                        ...
# 6080                       NaN
# 6088                       NaN
# 6096                       NaN
# 6104                       NaN
# 6112                       NaN
#
#                                           param_dim_red param_sel_ind__genexp  \
# 5742  StabilitySelectionTransformer(stability_scores...           passthrough
# 5870  StabilitySelectionTransformer(stability_scores...           passthrough
# 5998  StabilitySelectionTransformer(stability_scores...           passthrough
# 4406  StabilitySelectionTransformer(stability_scores...           passthrough
# 5750  StabilitySelectionTransformer(stability_scores...           passthrough
# ...                                                 ...                   ...
# 6080  StabilitySelectionTransformer(stability_scores...                  drop
# 6088  StabilitySelectionTransformer(stability_scores...                  drop
# 6096  StabilitySelectionTransformer(stability_scores...                  drop
# 6104  StabilitySelectionTransformer(stability_scores...                  drop
# 6112  StabilitySelectionTransformer(stability_scores...                  drop
#
#      param_sel_ind__gpa  ... param_clf__kernel  \
# 5742        passthrough  ...            linear
# 5870        passthrough  ...            linear
# 5998        passthrough  ...            linear
# 4406        passthrough  ...               NaN
# 5750        passthrough  ...            linear
# ...                 ...  ...               ...
# 6080               drop  ...               rbf
# 6088               drop  ...           sigmoid
# 6096               drop  ...           sigmoid
# 6104               drop  ...           sigmoid
# 6112               drop  ...           sigmoid
#
#                                                  params  split0_test_score  \
# 5742  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.980769
# 5870  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.980769
# 5998  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.980769
# 4406  {'clf': SGDClassifier(class_weight='balanced',...           0.980769
# 5750  {'clf': SVC(C=0.1, class_weight='balanced', ke...           0.980769
# ...                                                 ...                ...
# 6080  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6088  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6096  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6104  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
# 6112  {'clf': SVC(C=0.1, class_weight='balanced', ke...                NaN
#
#       split1_test_score  split2_test_score split3_test_score  \
# 5742           0.961538           0.953497          1.000000
# 5870           0.961538           0.953497          1.000000
# 5998           0.961538           0.953497          1.000000
# 4406           0.952448           0.962587          0.981818
# 5750           0.942308           0.944406          0.990909
# ...                 ...                ...               ...
# 6080                NaN                NaN               NaN
# 6088                NaN                NaN               NaN
# 6096                NaN                NaN               NaN
# 6104                NaN                NaN               NaN
# 6112                NaN                NaN               NaN
#
#       split4_test_score  mean_test_score  std_test_score rank_test_score
# 5742           0.961538         0.971469        0.016857               1
# 5870           0.961538         0.971469        0.016857               1
# 5998           0.961538         0.971469        0.016857               1
# 4406           0.923077         0.960140        0.021607               4
# 5750           0.942308         0.960140        0.021241               4
# ...                 ...              ...             ...             ...
# 6080                NaN              NaN             NaN            5502
# 6088                NaN              NaN             NaN            5457
# 6096                NaN              NaN             NaN            5463
# 6104                NaN              NaN             NaN            5468
# 6112                NaN              NaN             NaN            5473
#
# [6120 rows x 30 columns]
