# %%
import pandas as pd

# %%
res_cefta = pd.read_csv("results/grid_search/cv_results__Ceftazidim.csv")
res_cipro = pd.read_csv("results/grid_search/cv_results__Ciprofloxacin.csv")
res_colis = pd.read_csv("results/grid_search/cv_results__Colistin.csv")
res_merop = pd.read_csv("results/grid_search/cv_results__Meropenem.csv")
res_tobra = pd.read_csv("results/grid_search/cv_results__Tobramycin.csv")

# %%
res_cefta.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 5739        5739       1.239062      0.037612         0.237468
# 5867        5867       1.219919      0.029704         0.244244
# 5995        5995       1.259765      0.007900         0.257673
# 4412        4412       0.960486      0.003754         0.171623
# 4348        4348       0.963548      0.008783         0.174562
# ...          ...            ...           ...              ...
# 6080        6080       0.920349      0.013201         0.000000
# 6088        6088       0.910664      0.009353         0.000000
# 6096        6096       0.931995      0.015043         0.000000
# 6104        6104       0.936911      0.016184         0.000000
# 6112        6112       0.929975      0.028499         0.000000
#
#       std_score_time                                          param_clf  \
# 5739        0.004985  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...

# %%
res_cipro.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 6111        6111       1.391209      0.029422         0.280477
# 3647        3647       1.442767      0.021823         0.277105
# 4310        4310       1.142215      0.021393         0.208682
# 4406        4406       1.156940      0.020573         0.204657
# 3619        3619       1.388565      0.008051         0.268478
# ...          ...            ...           ...              ...
# 6080        6080       1.071723      0.043329         0.000000
# 6088        6088       1.041149      0.026360         0.000000
# 6096        6096       1.052251      0.009795         0.000000
# 6104        6104       1.070931      0.015215         0.000000
# 6112        6112       1.064898      0.020723         0.000000
#
#       std_score_time                                          param_clf  \
# 6111        0.008608  SVC(C=10.0, class_weight='balanced', kernel='s...
# ...

# %%
res_colis.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 4308        4308       1.281951      0.022587         0.230590
# 5739        5739       1.490256      0.021319         0.296960
# 5867        5867       1.563356      0.049948         0.308593
# 5995        5995       1.628470      0.065184         0.316997
# 5971        5971       1.617756      0.030023         0.311414
# ...          ...            ...           ...              ...
# 6080        6080       1.199404      0.023610         0.000000
# 6088        6088       1.237263      0.029375         0.000000
# 6096        6096       1.231703      0.006247         0.000000
# 6104        6104       1.212130      0.009802         0.000000
# 6112        6112       1.194144      0.015295         0.000000
#
#       std_score_time                                          param_clf  \
# 4308        0.005140  SGDClassifier(alpha=1e-05, class_weight='balan...
# ...

# %%
res_merop.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 5751        5751       1.285268      0.013665         0.246041
# 5879        5879       1.312666      0.051445         0.261085
# 6007        6007       1.395495      0.039410         0.278596
# 4391        4391       1.290656      0.029149         0.250137
# 5750        5750       1.061307      0.022455         0.189587
# ...          ...            ...           ...              ...
# 6080        6080       1.065307      0.007899         0.000000
# 6088        6088       1.027091      0.009205         0.000000
# 6096        6096       1.106133      0.077054         0.000000
# 6104        6104       1.078544      0.017685         0.000000
# 6112        6112       1.065363      0.056427         0.000000
#
#       std_score_time                                          param_clf  \
# 5751        0.011570  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...

# %%
res_tobra.sort_values(["mean_test_score", "std_test_score"], axis=0, ascending=False)
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 5742        5742       1.306008      0.023404         0.243198
# 5870        5870       1.342845      0.033486         0.238216
# 5998        5998       1.322032      0.024619         0.237451
# 4438        4438       1.323953      0.010498         0.237548
# 5750        5750       1.329500      0.022256         0.240054
# ...          ...            ...           ...              ...
# 6080        6080       1.193266      0.022626         0.000000
# 6088        6088       1.255182      0.014157         0.000000
# 6096        6096       1.224049      0.017508         0.000000
# 6104        6104       1.239759      0.023091         0.000000
# 6112        6112       1.218844      0.050470         0.000000
#
#       std_score_time                                          param_clf  \
# 5742        0.007059  SVC(C=0.1, class_weight='balanced', kernel='li...
# ...
