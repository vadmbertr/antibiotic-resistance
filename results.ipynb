# %%
import pandas as pd

# %%
res_cefta = pd.read_csv("results/cv_results__Ceftazidim.csv")
res_cipro = pd.read_csv("results/cv_results__Ciprofloxacin.csv")
res_colis = pd.read_csv("results/cv_results__Colistin.csv")
res_merop = pd.read_csv("results/cv_results__Meropenem.csv")
res_tobra = pd.read_csv("results/cv_results__Tobramycin.csv")

# %%
res_cefta
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 0              0       9.740937      0.451627         0.000000
# 1              1      24.100876      0.750050         0.882786
# 2              2      19.462941      0.513259         0.454636
# 3              3      33.707948      1.011824         0.982311
# 4              4      11.132529      0.360458         0.345537
# ...          ...            ...           ...              ...
# 5915        5915       9.060091      0.152732         0.342280
# 5916        5916       6.121652      0.285127         0.292003
# 5917        5917       7.899156      0.153311         0.320853
# 5918        5918       5.358129      0.549744         0.301068
# 5919        5919       5.469952      0.214946         0.290765
#
#       std_score_time                                          param_clf  \
# 0           0.000000                AdaBoostClassifier(random_state=15)
# ...

# %%
res_cipro
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 0              0      10.487400      0.168724         0.000000
# 1              1      24.605559      1.012396         0.901800
# 2              2      20.845261      0.450298         0.460860
# 3              3      35.619873      0.726125         1.053021
# 4              4      11.424882      0.627541         0.353274
# ...          ...            ...           ...              ...
# 5915        5915       9.686559      0.307988         0.340646
# 5916        5916       6.640516      0.210831         0.295182
# 5917        5917       8.839032      0.139239         0.317330
# 5918        5918       5.854246      0.766772         0.305939
# 5919        5919       5.560551      0.210801         0.296761
#
#       std_score_time                                          param_clf  \
# 0           0.000000                AdaBoostClassifier(random_state=15)
# ...

# %%
res_colis
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 0              0      11.913558      0.301997         0.000000
# 1              1      28.823637      1.186724         1.041741
# 2              2      23.630134      0.647436         0.471737
# 3              3      41.088628      0.825084         1.158188
# 4              4      13.215693      0.956862         0.369860
# ...          ...            ...           ...              ...
# 5915        5915      11.453275      0.417875         0.357811
# 5916        5916       7.717051      0.227773         0.296040
# 5917        5917       9.910208      0.095254         0.334755
# 5918        5918       7.238228      0.744717         0.322051
# 5919        5919       6.600277      0.393929         0.310514
#
#       std_score_time                                          param_clf  \
# 0           0.000000                AdaBoostClassifier(random_state=15)
# ...

# %%
res_merop
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 0              0      10.606296      0.261910         0.000000
# 1              1      24.571424      0.837245         0.910900
# 2              2      20.420836      0.603921         0.447287
# 3              3      36.255511      0.159699         1.042829
# 4              4      11.640588      0.596665         0.350477
# ...          ...            ...           ...              ...
# 5915        5915      10.077247      0.431485         0.348808
# 5916        5916       6.378430      0.617394         0.294395
# 5917        5917       7.739785      0.655478         0.324854
# 5918        5918       5.927189      0.309066         0.288411
# 5919        5919       6.077049      0.298910         0.297264
#
#       std_score_time                                          param_clf  \
# 0           0.000000  AdaBoostClassifier(learning_rate=0.1, random_s...
# ...

# %%
res_tobra
# Out:
#       Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  \
# 0              0      11.586318      0.537423         0.000000
# 1              1      27.479746      1.378427         0.983673
# 2              2      23.276912      0.267877         0.490102
# 3              3      40.680767      0.219802         1.155546
# 4              4      13.031603      0.293586         0.374530
# ...          ...            ...           ...              ...
# 5915        5915      10.883300      0.199060         0.367277
# 5916        5916       7.150990      0.347359         0.314693
# 5917        5917       9.674779      0.206152         0.337452
# 5918        5918       7.022861      0.905894         0.303505
# 5919        5919       6.492469      0.250018         0.334244
#
#       std_score_time                                          param_clf  \
# 0           0.000000                AdaBoostClassifier(random_state=15)
# ...
